# %% [markdown]
# <a href="https://colab.research.google.com/github/shivapri/ML/blob/master/keras_Artifical_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# %matplotlib inline

# %%
df= pd.read_csv('fake_reg.csv')

# %%
df
# Out:
#           price     feature1     feature2
# 0    461.527929   999.787558   999.766096
# 1    548.130011   998.861615  1001.042403
# 2    410.297162  1000.070267   998.844015
# 3    540.382220   999.952251  1000.440940
# 4    546.024553  1000.446011  1000.338531
# ..          ...          ...          ...
# 995  476.526078  1000.018988   999.672732
# 996  457.313186   998.855379  1000.020026
# 997  456.720992  1001.451646   998.847606
# 998  403.315576  1000.771023   998.562851
# 999  599.367093   999.232244  1001.451407
#
# [1000 rows x 3 columns]

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130011   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %%
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   price     1000 non-null   float64
#  1   feature1  1000 non-null   float64
#  2   feature2  1000 non-null   float64
# dtypes: float64(3)
# memory usage: 23.6 KB

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['feature1','feature2']].values

# %%
X
# Out:
# array([[ 999.78755752,  999.7660962 ],
#        [ 998.86161491, 1001.04240315],
#        [1000.07026691,  998.84401463],
#        ...,
#        [1001.45164617,  998.84760554],
#        [1000.77102275,  998.56285086],
#        [ 999.2322436 , 1001.45140713]])

# %%
y =df['price'].values

# %%
y
# Out:
# array([461.52792939, 548.13001146, 410.29716167, 540.38221981,
#        546.02455292, 542.9836716 , 555.48566416, 417.56972453,
#        373.14653122, 633.35029248, 624.24709206, 475.37241721,
#        600.36844486, 532.83295175, 472.8353628 , 506.31229096,
#        508.414406  , 610.4553519 , 323.65776198, 446.21230389,
#        362.12270299, 433.41064026, 562.00257647, 637.30962074,
#        522.80800754, 469.8028243 , 543.10992778, 565.43416994,
#        530.03285381, 610.58016503, 482.55641188, 327.56004052,
#        579.73083872, 448.42981468, 628.97709187, 536.79737216,
#        570.06729543, 357.82557519, 612.08492732, 444.67970846,
#        600.1186364 , 523.53312776, 512.94994495, 614.8813169 ,
#        404.35303251, 643.68851807, 488.95660398, 443.20468572,
#        514.47906638, 514.88174058, 325.05852217, 554.6620585 ,
#        451.39140001, 587.67887726, 477.73749721, 574.51560687,
#        548.9107991 , 528.69088356, 443.21100482, 397.88209319,
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
# array([[1001.63407565,  998.80950388],
#        [ 999.76150137,  998.41802414],
#        [ 998.2638401 , 1000.92030063],
#        ...,
#        [1000.47386523, 1001.44542815],
#        [ 998.8625673 ,  999.15662112],
#        [1000.55690247,  999.35441706]])

# %%
X_test
# Out:
# array([[ 999.54121558,  999.14114328],
#        [1000.61862216, 1001.11905081],
#        [1000.86079375, 1000.65496339],
#        [ 999.45851362, 1001.06368241],
#        [ 997.61547597,  999.57440788],
#        [1000.14086546, 1000.83393652],
#        [ 998.39657367, 1000.89778743],
#        [1000.48772914,  999.32129144],
#        [ 999.37620423, 1000.841348  ],
#        [1000.56800092,  999.15416846],
#        [1000.60331207, 1000.99323497],
#        [1001.96902295,  999.6666088 ],
#        [ 999.47784011,  999.32573058],
#        [ 999.15367572,  999.35665186],
#        [1002.56280406, 1000.55356428],
#        [1000.18750969,  999.21064524],
#        [1001.48563193,  999.42770753],
#        [ 999.31556397, 1002.1187026 ],
#        [1000.17527252, 1001.76025939],
#        [1001.02278582, 1000.28145855],
#        [ 998.2993191 ,  998.89970792],
#        [ 999.62911717,  999.54799684],
#        [ 998.77177786,  999.23169313],
#        [ 999.48763192,  998.86570158],
# ...

# %%
y_train
# Out:
# array([461.14062423, 353.78339461, 510.87857855, 711.65777328,
#        439.38667763, 512.04979227, 568.61318745, 466.49020065,
#        524.5896561 , 572.31305385, 613.42662915, 567.46368769,
#        481.53346268, 502.35831316, 361.96928555, 587.06918986,
#        457.77794629, 402.1955134 , 643.55257205, 490.99787402,
#        595.43348561, 655.42619806, 411.05157782, 341.68789552,
#        425.20422156, 535.54367583, 425.84365096, 368.9200954 ,
#        505.63188399, 489.79459784, 425.4599912 , 452.71044444,
#        521.7744574 , 565.24995494, 461.52792939, 493.01201779,
#        606.21795936, 509.84188626, 429.47259522, 413.10071452,
#        480.23012282, 602.12024979, 355.35228879, 402.00959595,
#        572.67843212, 333.08087339, 503.39000141, 378.81430465,
#        530.98717439, 434.69375374, 362.91867606, 567.19470601,
#        602.9701103 , 643.13593178, 527.61587693, 340.05814212,
#        519.46055247, 367.88499002, 489.09760772, 490.78489309,
# ...

# %%
y_test
# Out:
# array([402.29631873, 624.15619847, 582.4550663 , 578.58860646,
#        371.22410361, 584.38110772, 514.40564086, 464.11587006,
#        551.65009963, 451.8041724 , 613.95995262, 547.73198239,
#        428.31614877, 413.84178036, 654.83912076, 429.21452014,
#        512.04904895, 657.71868008, 674.31102047, 565.19184559,
#        338.0902386 , 450.9760715 , 375.13754715, 379.10982057,
#        562.05793604, 593.6677957 , 531.27754687, 423.65453319,
#        656.65474461, 412.90687671, 439.49653517, 488.78691774,
#        448.51914416, 685.21654079, 424.81078609, 418.45717839,
#        507.44318662, 550.14246248, 503.21614081, 397.88209319,
#        621.11885596, 411.57560703, 609.3840753 , 449.02606966,
#        503.51419982, 578.32901814, 664.50877632, 498.6284209 ,
#        316.9505926 , 478.35823792, 514.89474416, 374.19760282,
#        531.66193891, 405.40016562, 637.30962074, 482.55641188,
#        624.99250404, 624.24709206, 455.13953399, 484.46159148,
# ...

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train.max()
# Out:
# 1.0

# %%
X_train.min()
# Out:
# 0.0

# %%
X_test.max()
# Out:
# 1.0186515935232023

# %%
X_test.min()
# Out:
# -0.014108392024496652

# %%
help(Sequential)
# Out:
# Help on class Sequential in module tensorflow.python.keras.engine.sequential:
#
# class Sequential(tensorflow.python.keras.engine.functional.Functional)
#  |  `Sequential` groups a linear stack of layers into a `tf.keras.Model`.
#  |
#  |  `Sequential` provides training and inference features on this model.
#  |
#  |  Examples:
#  |
#  |  >>> # Optionally, the first layer can receive an `input_shape` argument:
#  |  >>> model = tf.keras.Sequential()
#  |  >>> model.add(tf.keras.layers.Dense(8, input_shape=(16,)))
#  |  >>> # Afterwards, we do automatic shape inference:
#  |  >>> model.add(tf.keras.layers.Dense(4))
#  |
#  |  >>> # This is identical to the following:
#  |  >>> model = tf.keras.Sequential()
#  |  >>> model.add(tf.keras.Input(shape=(16,)))
#  |  >>> model.add(tf.keras.layers.Dense(8))
#  |
#  |  >>> # Note that you can also omit the `input_shape` argument.
#  |  >>> # In that case the model doesn't have any weights until the first call
# ...

# %%
help(Dense)
# Out:
# Help on class Dense in module tensorflow.python.keras.layers.core:
#
# class Dense(tensorflow.python.keras.engine.base_layer.Layer)
#  |  Just your regular densely-connected NN layer.
#  |
#  |  `Dense` implements the operation:
#  |  `output = activation(dot(input, kernel) + bias)`
#  |  where `activation` is the element-wise activation function
#  |  passed as the `activation` argument, `kernel` is a weights matrix
#  |  created by the layer, and `bias` is a bias vector created by the layer
#  |  (only applicable if `use_bias` is `True`).
#  |
#  |  Note: If the input to the layer has a rank greater than 2, then `Dense`
#  |  computes the dot product between the `inputs` and the `kernel` along the
#  |  last axis of the `inputs` and axis 1 of the `kernel` (using `tf.tensordot`).
#  |  For example, if input has dimensions `(batch_size, d0, d1)`,
#  |  then we create a `kernel` with shape `(d1, units)`, and the `kernel` operates
# ...

# %%
model = Sequential([Dense(4,activation='relu'),Dense(2,activation='sigmoid'),Dense(1)])

# %%
model

# %%
model = Sequential()

model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1))
model.compile(optimizer='rmsprop', loss='mse')

# %%
model

# %%
model.fit(x=X_train,y=y_train,epochs=250)
# Out:
# Epoch 1/250
# 22/22 [==============================] - 0s 1ms/step - loss: 256681.8906
# Epoch 2/250
# 22/22 [==============================] - 0s 1ms/step - loss: 256580.2500
# Epoch 3/250
# 22/22 [==============================] - 0s 1ms/step - loss: 256464.3438
# Epoch 4/250
# 22/22 [==============================] - 0s 1ms/step - loss: 256321.3438
# Epoch 5/250
# 22/22 [==============================] - 0s 1ms/step - loss: 256147.7656
# Epoch 6/250
# 22/22 [==============================] - 0s 1ms/step - loss: 255940.7500
# Epoch 7/250
# 22/22 [==============================] - 0s 1ms/step - loss: 255694.3750
# Epoch 8/250
# 22/22 [==============================] - 0s 1ms/step - loss: 255397.4375
# Epoch 9/250
# 22/22 [==============================] - 0s 1ms/step - loss: 255040.9375
# Epoch 10/250
# 22/22 [==============================] - 0s 1ms/step - loss: 254619.4531
# Epoch 11/250
# 22/22 [==============================] - 0s 1ms/step - loss: 254126.7812
# Epoch 12/250
# ...

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
plt.figure(figsize=(15,8))
loss_df.plot()

# %%
model.evaluate(X_test,y_test)
# Out:
# 10/10 [==============================] - 0s 1ms/step - loss: 25.3623
# 25.362266540527344

# %%
model.evaluate(X_train,y_train)
# Out:
# 22/22 [==============================] - 0s 939us/step - loss: 24.9187
# 24.918651580810547

# %%
test_predictions = model.predict(X_test)

# %%
test_predictions = pd.Series(test_predictions.reshape(300,))

# %%
test_predictions
# Out:
# 0      404.595245
# 1      622.681519
# 2      591.296387
# 3      571.408630
# 4      365.954987
#           ...
# 295    528.259521
# 296    514.514954
# 297    608.803589
# 298    416.250000
# 299    410.178650
# Length: 300, dtype: float32

# %%
pred_df = pd.DataFrame(columns=['Test True Y','Model Predictions'])

# %%
pred_df.drop(['Test True Y','Model Predictions'],axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.concat([pred_df,test_predictions,y_test],axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-4cd9c7c1d154> in <module>()
# ----> 1 pd.concat([pred_df,test_predictions,y_test],axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     355                     "only Series and DataFrame objs are valid".format(typ=type(obj))
#     356                 )
# --> 357                 raise TypeError(msg)
#     358
#     359             # consolidate
#
# ...

# %%
type(y_test)
# Out:
# numpy.ndarray

# %%
y_test_val = pd.Series(y_test)

# %%
y_test_val
# Out:
# 0      402.296319
# 1      624.156198
# 2      582.455066
# 3      578.588606
# 4      371.224104
#           ...
# 295    525.704657
# 296    502.909473
# 297    612.727910
# 298    417.569725
# 299    410.538250
# Length: 300, dtype: float64

# %%
pred_df = pd.concat([pred_df,test_predictions,y_test_val],axis=1).drop(['Test True Y','Model Predictions'],axis=1)

# %%
pred_df
# Out:
#               0           1
# 0    404.595245  402.296319
# 1    622.681519  624.156198
# 2    591.296387  582.455066
# 3    571.408630  578.588606
# 4    365.954987  371.224104
# ..          ...         ...
# 295  528.259521  525.704657
# 296  514.514954  502.909473
# 297  608.803589  612.727910
# 298  416.250000  417.569725
# 299  410.178650  410.538250
#
# [300 rows x 2 columns]

# %%
y_test
# Out:
# array([402.29631873, 624.15619847, 582.4550663 , 578.58860646,
#        371.22410361, 584.38110772, 514.40564086, 464.11587006,
#        551.65009963, 451.8041724 , 613.95995262, 547.73198239,
#        428.31614877, 413.84178036, 654.83912076, 429.21452014,
#        512.04904895, 657.71868008, 674.31102047, 565.19184559,
#        338.0902386 , 450.9760715 , 375.13754715, 379.10982057,
#        562.05793604, 593.6677957 , 531.27754687, 423.65453319,
#        656.65474461, 412.90687671, 439.49653517, 488.78691774,
#        448.51914416, 685.21654079, 424.81078609, 418.45717839,
#        507.44318662, 550.14246248, 503.21614081, 397.88209319,
#        621.11885596, 411.57560703, 609.3840753 , 449.02606966,
#        503.51419982, 578.32901814, 664.50877632, 498.6284209 ,
#        316.9505926 , 478.35823792, 514.89474416, 374.19760282,
#        531.66193891, 405.40016562, 637.30962074, 482.55641188,
#        624.99250404, 624.24709206, 455.13953399, 484.46159148,
# ...

# %%
y_test_val
# Out:
# 0      402.296319
# 1      624.156198
# 2      582.455066
# 3      578.588606
# 4      371.224104
#           ...
# 295    525.704657
# 296    502.909473
# 297    612.727910
# 298    417.569725
# 299    410.538250
# Length: 300, dtype: float64

# %%
pred_df.columns= ['Model Predictions','Test True Y']

# %%
pred_df
# Out:
#      Model Predictions  Test True Y
# 0           404.595245   402.296319
# 1           622.681519   624.156198
# 2           591.296387   582.455066
# 3           571.408630   578.588606
# 4           365.954987   371.224104
# ..                 ...          ...
# 295         528.259521   525.704657
# 296         514.514954   502.909473
# 297         608.803589   612.727910
# 298         416.250000   417.569725
# 299         410.178650   410.538250
#
# [300 rows x 2 columns]

# %%
sns.scatterplot(x='Model Predictions',y='Test True Y',data=pred_df)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(pred_df['Test True Y'],pred_df['Model Predictions'])
# Out:
# 4.033339617021535

# %%
mean_squared_error(pred_df['Test True Y'],pred_df['Model Predictions'])
# Out:
# 25.36227019960842

# %%
df
# Out:
#           price     feature1     feature2
# 0    461.527929   999.787558   999.766096
# 1    548.130011   998.861615  1001.042403
# 2    410.297162  1000.070267   998.844015
# 3    540.382220   999.952251  1000.440940
# 4    546.024553  1000.446011  1000.338531
# ..          ...          ...          ...
# 995  476.526078  1000.018988   999.672732
# 996  457.313186   998.855379  1000.020026
# 997  456.720992  1001.451646   998.847606
# 998  403.315576  1000.771023   998.562851
# 999  599.367093   999.232244  1001.451407
#
# [1000 rows x 3 columns]

# %%
new_gem = [[1001,999]]

# %%
new_gem = scaler.transform(new_gem)

# %%
new_gem
# Out:
# array([[0.63589681, 0.36005236]])

# %%
model.predict(new_gem)
# Out:
# array([[450.4186]], dtype=float32)

# %%
from tensorflow.keras.models import load_model

# %%
model.save('my_first_ann_reg.h5')

# %%
later_model = load_model('my_first_ann_reg.h5')

# %%
later_model.predict(new_gem)
# Out:
# array([[450.4186]], dtype=float32)
